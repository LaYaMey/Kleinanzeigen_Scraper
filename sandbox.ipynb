# %%
import requests

# The API endpoint
url = "https://www.kleinanzeigen.de"

# A GET request to the API
response = requests.get(url)

# Print the response
response_json = response.json()
print(response_json)
# Out:
# {'title': 'IP-Bereich vorübergehend gesperrt.', 'message': 'In deinem IP-Bereich kam es vor Kurzem mehrfach zu unsicheren Versuchen, unsere Plattform zu verwenden.  Dies kann auch durch andere Personen erfolgt sein. Daher wurde dieser IP-Bereich zur Vorbeugung von Betrug zeitweilig von der Nutzung von Kleinanzeigen ausgeschlossen. Bitte versuche es später erneut.', 'more': 'Mehr informationen: https://themen.kleinanzeigen.de/ip-eingeschraenkt/', 'ref': 'Ref#: 0.e571060.1705236535.169e95d2  IP#: 139.47.53.167'}
